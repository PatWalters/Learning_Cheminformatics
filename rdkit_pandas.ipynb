# %%
from rdkit.Chem import PandasTools
from rdkit.Chem import Draw
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole

# %%
df = PandasTools.LoadSDF("data/ch05_compounds.sdf")
df.head(3)
# Out:
#   ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <img src="data:image/png;base64,..." alt="Mol"/>  CHEMBL281692
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <img src="data:image/png;base64,..." alt="Mol"/>  CHEMBL430726
# 2     <img src="data:image/png;base64,..." alt="Mol"/>  CHEMBL281430

# %%
from IPython.display import SVG
im=Draw.MolsToGridImage(df.ROMol.tolist(), useSVG=True,molsPerRow=5)
SVG(im)

# %%
from rdkit.Chem import rdDepictor

# %%
_ = [rdDepictor.Compute2DCoords(x) for x in df.ROMol]

# %%
im=Draw.MolsToGridImage(df.ROMol.tolist(), useSVG=True,molsPerRow=5)
SVG(im)

# %%
from rdkit.Chem import rdFMCS

# %%
res = rdFMCS.FindMCS(df.ROMol, completeRingsOnly=True, atomCompare=rdFMCS.AtomCompare.CompareAny)

# %%
MCS = Chem.MolFromSmarts(res.smartsString)
rdDepictor.Compute2DCoords(MCS)
MCS

# %%
from rdkit.Chem import TemplateAlign

# %%
_= [TemplateAlign.AlignMolToTemplate2D(x, MCS) for x in df.ROMol]

# %%
im=Draw.MolsToGridImage(df.ROMol.tolist(), useSVG=True,molsPerRow=5)
SVG(im)
